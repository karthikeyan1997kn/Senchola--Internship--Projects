# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("D:\Downloads\Telegram Desktop\Batch-2 Senchola application details.xlsx")
df.head()
df.tail()
# Out:
#                   Timestamp Are you open to learn ?  \
# 424 2023-06-20 21:49:46.335                     Yes
# 425 2023-06-21 17:17:28.469                     Yes
# 426 2023-06-22 10:50:39.815                     Yes
# 427 2023-06-22 20:45:48.865                     Yes
# 428 2023-06-23 12:28:08.511                     Yes
#
#                    Why you want to join this program ? Do you have laptop   \
# 424  I'm a graduate in mechanical engineering. I wi...                 Yes
# 425          I wish to switch my career into IT side.                  Yes
# 426  I want to become a highly skilled data scienti...                 Yes
# 427                                           Need job                 Yes
# 428  Becouse, I am a low middle class boy.I want to...                 Yes
#
#                   Name                                             Address  \
# 424    Kamalesh Kannan   4/4, mela street, vandrampalayam, puthurpalaya...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            429 non-null    datetime64[ns]
#  1   Are you open to learn ?              429 non-null    object
#  2   Why you want to join this program ?  429 non-null    object
#  3   Do you have laptop                   429 non-null    object
#  4   Name                                 429 non-null    object
#  5   Address                              429 non-null    object
#  6   Qualification                        429 non-null    object
#  7   Degree                               429 non-null    object
#  8   Pass-out Year                        429 non-null    object
#  9   College Name                         429 non-null    object
#  10  City                                 429 non-null    object
# ...

# %%
df.describe()
# Out:
#                            Timestamp
# count                            429
# mean   2023-06-02 16:51:55.194179328
# min       2023-05-30 18:51:45.391000
# 25%    2023-05-31 14:29:08.288999936
# 50%    2023-05-31 21:29:15.670000128
# 75%       2023-06-02 22:46:20.804000
# max       2023-06-23 12:28:08.511000

# %%
dfc = df.copy()
dfc = dfc.drop(dfc.columns[[0,2,4]],axis=1)

# %%
dfc = dfc.drop(dfc.columns[2],axis = 1)
dfc
# Out:
#     Are you open to learn ? Do you have laptop    Qualification  \
# 0                       Yes                 Yes     Engineering
# 1                       Yes                 Yes          Others
# 2                       Yes                 Yes  Arts & Science
# 3                       Yes                 Yes  Arts & Science
# 4                       Yes                 Yes  Arts & Science
# ..                      ...                 ...             ...
# 424                     Yes                 Yes     Engineering
# 425                     Yes                 Yes     Engineering
# 426                     Yes                 Yes  Arts & Science
# 427                     Yes                 Yes  Arts & Science
# 428                     Yes                 Yes  Arts & Science
#
#                                             Degree Pass-out Year  \
# 0    B.E Electronics and communication engineering          2021
# ...

# %%
dfc.shape
# Out:
# (429, 12)

# %%
dfc.Qualification.unique()
# Out:
# array(['Engineering', 'Others', 'Arts & Science', 'Diploma', 'HS / HSS'],
#       dtype=object)

# %%
udegree = dfc.Degree.unique()
udegree = sorted(map(str, udegree))
udegree
# Out:
# [' BE.computer science and engineering',
#  '12',
#  'Agriculture engineering',
#  'B .E(electronics and instrumentation)',
#  'B .tech IT',
#  'B E - Mechanical',
#  'B E, MECHANICAL',
#  'B E. Computer Science ',
#  'B Tech IT',
#  'B Tech information Technology ',
#  'B Tech(Information Technology)',
#  'B sc',
#  'B sc ',
#  'B sc computer science',
#  'B sc computer science ',
#  'B. A - History',
#  'B. Com',
#  'B. E',
#  'B. E computer science (still studying )  below the year of pass out was fake sorry for that one',
#  'B. E-EEE',
#  'B. E-computer science and engineering ',
#  'B. SC BIOINFORMATICS',
#  'B. Sc',
#  'B. Sc Mathematics',
#  'B. Sc Physics',
#  'B. Tech',
#  'B. Tech (IT) ',
#  'B. Tech (Information technology) ',
#  'B. Tech - CHEMICAL ENGINEERING',
#  'B. Tech - ECE',
#  'B. Tech(IT) ',
#  'B. Tech,Chemical Engineering ',
#  'B.A English',
#  'B.A English literature ',
#  'B.A., English ',
#  'B.COM',
#  'B.E',
#  'B.E ',
#  'B.E (EEE)',
#  'B.E - CSE',
# ...

# %%
ustate = dfc.State.unique()
ustate = sorted(map(str,ustate))
ustate
# Out:
# [' Tiruvannamalai',
#  'Andhra Pradesh',
#  'Erode ',
#  'India',
#  'Kerala',
#  'Namakkal',
#  'Pondicherry',
#  'Pondicherry ',
#  'Puducherry',
#  'Puducherry ',
#  'TAMIL NADU',
#  'TAMIL NADU ',
#  'TAMILNADU',
#  'TAMILNADU ',
#  'Tamil Nadu',
#  'Tamil Nadu ',
#  'Tamil nadhu',
#  'Tamil nadu',
#  'Tamil nadu ',
#  'TamilNadu',
#  'TamilNadu ',
#  'Tamilnadu',
#  'Tamilnadu ',
#  'Tamilnadu -Salem ',
#  'karur',
#  'tamil nadu',
#  'tamil nadu ',
#  'tamilnadu',
#  'tamilnadu ']

# %%
dfc.loc[dfc["State"] == 'India']
# Out:
#     Are you open to learn ? Do you have laptop  Qualification   Degree  \
# 137                     Yes                 Yes   Engineering  B. Tech
#
#     Pass-out Year                                College Name         City  \
# 137          2023  Sri manakula vinayagar engineering college  Pondicherry
#
#      State What you wan to learn ? Technical Feeback by  \
# 137  India     Flutter Development              Vignesh
#
#                                     Technical Comments HR Comments
# 137  he is studing college 2nd year so he can't man...         NaN

# %%
bedeg = [' BE.computer science and engineering','B .E(electronics and instrumentation)',
 'B E - Mechanical',
 'B E, MECHANICAL',
 'B E. Computer Science ', 'B. E',
 'B. E computer science (still studying )  below the year of pass out was fake sorry for that one',
 'B. E-EEE',
 'B. E-computer science and engineering ','B.E',
 'B.E ',
 'B.E (EEE)',
 'B.E - CSE',
 'B.E COMPUTER SCIENCE AND ENGINEERING ',
 'B.E CSE',
 'B.E CSE ( Studying)  sir below this my year of pass out is fake sorry for that ',
 'B.E Civil Engineering ',
 'B.E Computer science and engineering',
 'B.E E.C.E',
 'B.E ECE',
 'B.E Electrical and Electronic Engineering ',
 'B.E Electronics and communication engineering',
 'B.E MECHANICAL ',
 'B.E Mechanical ',
 'B.E mechanical',
 'B.E(CSE)',
 'B.E(CSE) ',
 'B.E(ECE)',
 'B.E.',
 'B.E. (Computer Science and Engineering)',
 'B.E. - Computer Science and Engineering ',
 'B.E. Electronic and Instrumentation Engineering ',
 'B.E. computer science and engineering ',
 'B.E.CSE',
 'B.E.CSE ',
 'B.E.Computer Science and Engineering',
 'B.E/MECHANICAL ENGINEERING ', 'BE',
 'BE ',
 'BE (CSE)',
 'BE (computer science and engineering)',
 'BE - COMPUTER SCIENCE AND ENGINEERING',
 'BE - EEE',
 'BE - Mechanical Engineering ',
 'BE - mechanical engineering ',
 'BE Biomedical Engineering ',
 'BE COMPUTER SCIENCE AND ENGINEERING ',
 'BE CSE',
 'BE CSE ',
 'BE ECE',
 'BE ECE ',
 'BE EEE',
 'BE Electronic and Communication Engineering ',
 'BE MECHANICAL ENGINEERING',
 'BE MECHANICAL ENGINEERING ',
 'BE Mechanical Engineering',
 'BE Mechanical Engineering ',
 'BE computer Science and engineering',
 'BE computer science and engineering ',
 'BE mechanical ',
 'BE mechanical engineering ',
 'BE(CSE)',
 'BE(Computer Science and Engineering)',
 'BE, CSE ',
 'BE- Mechanical Engineering ',
 'BE-ECE',
 'BE-ECE ',
 'BE. Computer Science and Engineering ',
 'BE. ECE',
 'BE. Mechanical',
 'BE.,',
 'BE.CIVIL','mechanical'
 'BE.CSE',
 'BE/ECE''B.e computer Science ',
 'B.e. Mech','Be','B.E','Bachelor of Engineering (CSE)',
 'Bachelor of Engineering (Electrical and Electronics Engineering)',
 'Bachelor of engineering ',
'COMPUTER SCIENCE AND ENGINEERING ',
'CSE',
'Civil Engineering',
 'Civil engineering ',
 'Computer Science and Engineering ',
'Computer science and engineering',
 'Computer science and engineering ',
 'Computer science engineering ',
 'Computers Engineering',
'Cse','ECE, BE',
 'EEE',
 'EIE',
 'Electrical and electronics engineering ',
 'Electronic And Communication Engineering ',
 'Electronics and Communication Engineering',
 'Electronics and Communication Engineering ',
 'Electronics and communication ',
 'Electronics and communication Engineering',
 'Electronics and communication engineering ','Mechanical',
 'Mechanical ',
 'Mechanical Engineering',
 'Mechanical engineering',
 'Mechanical engineering ','B.e computer Science ','mechanical','BE.CSE',
 'BE/ECE']

btecdeg = [
 'Agriculture engineering',
 'B .tech IT',
 'B Tech IT',
 'B Tech information Technology ',
 'B Tech(Information Technology)',
 'B. Tech',
 'B. Tech (IT) ',
 'B. Tech (Information technology) ',
 'B. Tech - CHEMICAL ENGINEERING',
 'B. Tech - ECE',
 'B. Tech(IT) ',
 'B. Tech,Chemical Engineering ',
 'B.Tech',
 'B.Tech (Biotechnology)',
 'B.Tech (IT)',
 'B.Tech - ECE',
 'B.Tech - Information Technology',
 'B.Tech - Information technology ',
 'B.Tech Artificial Intelligence and Data Science (2025)',
 'B.Tech IT',
 'B.Tech Information Technology ',
 'B.Tech in IT',
 'B.Tech(IT)',
 'B.Tech-I.T.',
 'B.tech',
 'B.tech (mechanical engineering)',
 'B.tech / Information technology ',
 'B.tech Chemical Engineering ',
 'B.tech EEE',
 'BTECH -IT',
 'Btech',
 'Btech(IT)',
 'IT',
 'Information Technology',
 'Information Technology( IT )' 'B.Tech','BIOMEDICAL ENGINEERING']

bscdeg = [ 'B sc',
 'B sc ',
 'B sc computer science',
 'B sc computer science ',
 'B. SC BIOINFORMATICS',
 'B. Sc',
 'B. Sc Mathematics',
 'B. Sc Physics',
 'B.Sc ',
 'B.Sc (mathematics)',
 'B.Sc Computer Science ',
 'B.Sc Mathematics ',
 'B.Sc Physics ',
 'B.Sc.CS',
 'B.Sc.Mathematics',
 'B.sc',
 'B.sc Computer Science ',
 'B.sc Computer science ',
 'B.sc INFORMATION TECHNOLOGY',
 'B.sc chemistry ',
 'B.sc information technology',
 'B.sc information technology and management ',
 'B.sc mathematics ',
 'B.sc physics ',
 'B.sc(Food Science& Nutrition)',
 'B.sc(multimedia and web technology)',
 'BCS',
 'BSC (Physics), SJC, Trichy.... MBA (HR and Finance), SHC, Vellore',
 'BSC COMPUTER SCIENCE ',
 'BSC VISUAL COMMUNICATION ',
 'BSC.INFORMATION TECHNOLOGY',
 'BSc Computer Science ',
 'BSc Maths With Computer application ',
 'Bsc',
 'Bsc ',
 'Bsc Computer Science ',
 'Bsc Computer science ',
 'Bsc Forensic science ',
 'Bsc IT',
 'Bsc Mathamatics ',
 'Bsc Physics ',
 'Bsc computer science',
 'Bsc computer science ',
 'Bsc cs',
 'Bsc forensic science ',
 'Bsc mathematics ',
 'Bsc(CS)',
 'Bsc.Trauma care management ','B.Sc', "Bachelor's in computer science",'Computer Science',
 'Computer Science ',
 'Computer science ',
 'Cs','Studying in bsc biology ',
 'b.sc  - computer science','Mathematics','Biotechnology ',
 'Catering technology ','Information Technology( IT )']

badeg = ['B. A - History',
'B.A English',
 'B.A English literature ',
 'B.A., English ',]

bcomdeg = [ 'B. Com',
 'B.COM',
 'B.com',
 'B.com CA',
 'B.com corporate secretaryship ',
 'B.com with Computer Application ',
 'Bcom',
 'Bcom Computer Applications ',
 'b.com','Bachelor of Commerce (BCOM)',
 'Bachelor of commerce ']

bcadeg = [ 'BCA',
 'BCA ',
 'BCA(bachelor of computer applications)',
 'BCA(computer application)',
 'Bachelor Of Computer Application ',
'Bachelor of Computer Application',
'Bachelor of Computer Application ',
 'Bachelor of computer application',
 'Bachelor of computer application (BCA)',
 'Bachelor of computer applications ',
 "Bachelor's of computer Application",
 'Bca','BACHELOR OF COMPUTER APPLICATION']

nodeg = [12,'No dedree']

bbadeg = [ 'BBA',
 'BBA -CA ']

barchdeg = ['Bachelor in Architecture']

dip = ['Diploma ',
 'Diploma in Electrical and Electronic Engineering ',
 'Diploma in Electrical and Electronics Engineering ',
 'Diploma in Electrical and electronics engineering ',
 'Diploma in agriculture',
 'Diploma in computer engineering ']

mscdeg = [ 'M. Sc Mathematics',
 'M.Sc Mathematics',
 'M.Sc Mathematics ',
 'M.Sc maths ',
 'M.Sc. Chemistry ',
 'M.sc',
 'M.sc mathematics ',
 'M.sc(Computer Science)',
 'M.sc.Data Analytics ',
 'Msc',
 'Msc computer science ',
 'Msc cs',
 'Msc in Mathematics','msc (CT)','MSc Mathematics ','Master of Science']

mbadeg = ['MBA',
 'MBA ',
 'MBA (HR)',
 'MBA (HRM)',
 'MBA - ONLINE',
 'MBA HR',
 'MBA-HR', 'M.B.A., (finance)','Mba ']

mcadeg = [ 'M. C. A',
 'MCA',
 'MCA ',
'Masters of Computer Applications ',
'Mca',
'mca']

medeg = ['M.E',
 'M.E Computer science and engineering ',
'ME',
 'ME Thermal Engineering']

# %%
dfc['Degree'] = dfc['Degree'].replace(bedeg, 'B.E')
dfc['Degree'] = dfc['Degree'].replace(btecdeg, 'B.Tech')
dfc['Degree'] = dfc['Degree'].replace(bscdeg, 'B.Sc')
dfc['Degree'] = dfc['Degree'].replace(badeg, 'B.A')
dfc['Degree'] = dfc['Degree'].replace(bcomdeg, 'B.Com')
dfc['Degree'] = dfc['Degree'].replace(bcadeg, 'BCA')
dfc['Degree'] = dfc['Degree'].replace(nodeg, 'NO DEGREE')
dfc['Degree'] = dfc['Degree'].replace(bbadeg, 'BBA')
dfc['Degree'] = dfc['Degree'].replace(barchdeg, 'B.Arch')
dfc['Degree'] = dfc['Degree'].replace(dip, 'Diploma')
dfc['Degree'] = dfc['Degree'].replace(mscdeg, 'M.Sc')
dfc['Degree'] = dfc['Degree'].replace(mbadeg, 'MBA')
dfc['Degree'] = dfc['Degree'].replace(mcadeg, 'MCA')
dfc['Degree'] = dfc['Degree'].replace(medeg, 'M.E')

# %%
udegree = dfc.Degree.unique()
udegree = sorted(map(str, udegree))
udegree
# Out:
# ['B.A',
#  'B.Arch',
#  'B.Com',
#  'B.E',
#  'B.Sc',
#  'B.Tech',
#  'BBA',
#  'BCA',
#  'Diploma',
#  'M.E',
#  'M.Lib.I.Sc',
#  'M.Sc',
#  'MBA',
#  'MCA',
#  'NO DEGREE']

# %%
dfc
# Out:
#     Are you open to learn ? Do you have laptop    Qualification Degree  \
# 0                       Yes                 Yes     Engineering    B.E
# 1                       Yes                 Yes          Others    BCA
# 2                       Yes                 Yes  Arts & Science    B.A
# 3                       Yes                 Yes  Arts & Science    BCA
# 4                       Yes                 Yes  Arts & Science   M.Sc
# ..                      ...                 ...             ...    ...
# 424                     Yes                 Yes     Engineering    B.E
# 425                     Yes                 Yes     Engineering    B.E
# 426                     Yes                 Yes  Arts & Science   M.Sc
# 427                     Yes                 Yes  Arts & Science   B.Sc
# 428                     Yes                 Yes  Arts & Science  B.Com
#
#     Pass-out Year        City      State                Course
# ...

# %%
ucity = dfc.City.unique()
ucity=sorted(map(str,ucity))
ucity
# Out:
# ['Ariyalur',
#  'Aruppukottai, Virudhunagar',
#  'Aundipatti',
#  'Chennai',
#  'Cheyyar',
#  'Chinnasalem ',
#  'Chittoor',
#  'Coimbatore',
#  'Cuddalore',
#  'Dharmapuri',
#  'Dindugal',
#  'Erode',
#  'Gobichettipalayam ',
#  'Gowrivakkam',
#  'Hosur',
#  'KARUR',
#  'KRISHNAGIRI ',
#  'Kallakurichi ',
#  'Kanchipuram',
#  'Karaikal',
#  'Karaikudi',
#  'Kariapatti',
#  'Karur',
#  'Kovilpatti',
#  'Krishnagiri ',
#  'Kumbakonam',
#  'Lalgudi',
#  'MUDUKULATHUR',
#  'Madurai',
#  'Mailadurai',
#  'Mannarkkad',
#  'Mannarkudi',
#  'Marthandam ',
#  'Mayiladuthurai ',
#  'Nagapattinam',
#  'Nagercoil ',
#  'Namakkal',
#  'Nannilam',
#  'Nellore',
#  'Ooty',
#  'Panruti ',
#  'Papanasam ',
#  'Paramakudi',
#  'Perambalur',
#  'Pollachi ',
#  'Puducherry',
#  'Pudukotai',
#  'Rajapalayam',
#  'Ramanathapuram',
#  'Rameshwaram ',
#  'Ranipet',
#  'Salem',
#  'Sankagiri RS',
#  'Sankarankovil ',
#  'Sathyamangalam ',
#  'Sattur',
#  'Sayalkudi',
#  'Surandai ',
#  'TIRUPATTUR ',
# ...

# %%
Ariyalurcity = ['Ariyalur','Ariyalur ']

chennaicity =[ 'Avadi','CHENNAI','Chengalpet','Chennai','Chennai ','Chennal ','Chennnai ','Redhills ','THIRUVALLUR','Thirumangalam','chennai',
'chennai 600073','India ','Poonamallee','Thiruvallur','Thiruvallur ','Nazarathpettai (Chennai)']

kovaicity=['COIMBATORE','COIMBATORE ','Coimbatore','Coimbatore ','coimbatore']
 
kadalurcity = ['Cuddalore','Cuddalore ','Cuddalore District']

dharmcity = ['Dharmapuri','Dharmapuri ']

dingducity =[ 'Dindigul','Dindigul ','Dindugal ']

erodcity = [ 'Erode','Erode ','Erode(Anthiyur)','erode']

hosurcity = ['Hosur','Hosur ']

kanchicity = ['KANCHIPURAM','Kanchipuram','Kanchipuram ']

Krishnacity = ['Krishnagiri ','KRISHNAGIRI ']

karaikalcity = ['Karaikal','Karaikal ']

karakudicity = ['Karaikudi','Karaikudi ', 'karaikudi']

karurcity =[ 'Karur','Karur ','KARUR']

maduraicity = ['MADURAI','Madurai','Madurai ']
 
mannarkudicity=['Mannargudi','Mannargudi ']

nammakalcity = ['NAMAKKAL','Namakkal','Namakkal ']

paramakudicity = [ 'PARAMAKUDI','Paramakudi']

perambalurcity = ['Perambalur','Perambalur ','Perambalur District']

puduchercity = ['Pondicherry','Puducherry','Puducherry ']
 
pudukotaicity=[ 'Pudukkottai','Pudukkottai ']
 
ranipettaicity =['RANIPET','Ranipettai','ranipettai']
 
ramanathapuramcity = ['Ramanathapuram','Ramanathapuram ']

salemcity= ['SALEM ','Salem','Salem-636005 ']

tirichycity = ['TIRUCHIRAPALLI','TRICHY','Tiruchirapalli','Tiruchirapalli ','Tiruchirappalli', 'Trichirappalli ','Trichy','Trichy ',]

tanjorecity = ['Tanjore','Thanjavur','Thanjavur ']

tenkasicity = ['Tenkasi','Tenkasi ','Pavoorchatram - Tenkasi district']
 
thirunelvelicity = ['Thirunelveli','Tirunelveli','Tirunelveli ']

thiruvarurcity=[ 'Thiruvarur','Thiruvarur ']

tiruchendurcity = ['Tiruchendur','Tiruchendur ']
 
tirupatturcity =  ['Tirupattur','Tirupattur ','TIRUPATTUR','TIRUPATTUR ']

tiruppurcity = ['Tiruppur','Tiruppur ','Tirupur','Tirupur ','Tiurpur ']

vellorecity = ['VELLORE','Vellore','Vellore ','Vellore District ']

villupuramcity = ['Villupuram','Villupuram ']

virudhunagarcity = ['Virudhunagar','Virudhunagar ','Aruppukottai, Virudhunagar']

# %%
dfc['City']=dfc['City'].replace(Ariyalurcity,'Ariyalur')
dfc['City']=dfc['City'].replace(chennaicity,'Chennai')
dfc['City']=dfc['City'].replace(kovaicity,'Coimbatore')
dfc['City']=dfc['City'].replace(kadalurcity,'Cuddalore')
dfc['City']=dfc['City'].replace(dharmcity,'Dharmapuri')
dfc['City']=dfc['City'].replace(dingducity,'Dindugal')
dfc['City']=dfc['City'].replace(erodcity,'Erode')
dfc['City']=dfc['City'].replace(hosurcity,'Hosur')
dfc['City']=dfc['City'].replace(kanchicity,'Kanchipuram')
dfc['City']=dfc['City'].replace(karaikalcity,'Karaikal')
dfc['City']=dfc['City'].replace(karakudicity,'Karaikudi')
dfc['City']=dfc['City'].replace(karurcity,'Karur')
dfc['City']=dfc['City'].replace(maduraicity,'Madurai')
dfc['City']=dfc['City'].replace(mannarkudicity,'Mannarkudi')
dfc['City']=dfc['City'].replace(nammakalcity,'Namakkal')
dfc['City']=dfc['City'].replace(paramakudicity,'Paramakudi')
dfc['City']=dfc['City'].replace(perambalurcity,'Perambalur')
dfc['City']=dfc['City'].replace(puduchercity,'Puducherry')
dfc['City']=dfc['City'].replace(pudukotaicity,'Pudukotai')
dfc['City']=dfc['City'].replace(ranipettaicity,'Ranipet')
dfc['City']=dfc['City'].replace(ramanathapuramcity,'Ramanathapuram')
dfc['City']=dfc['City'].replace(salemcity,'Salem')
dfc['City']=dfc['City'].replace(tirichycity,'Trichy')
dfc['City']=dfc['City'].replace(tanjorecity,'Tanjore')
dfc['City']=dfc['City'].replace(tenkasicity,'Tenkasi')
dfc['City']=dfc['City'].replace(thirunelvelicity,'Tirunelveli')
dfc['City']=dfc['City'].replace(thiruvarurcity,'Thiruvarur')
dfc['City']=dfc['City'].replace(tiruchendurcity,'Tiruchendur')
dfc['City']=dfc['City'].replace(tirupatturcity,'Tirupattur')
dfc['City']=dfc['City'].replace(tiruppurcity,'Tiruppur')
dfc['City']=dfc['City'].replace(vellorecity,'Vellore')
dfc['City']=dfc['City'].replace(villupuramcity,'Villupuram')
dfc['City']=dfc['City'].replace(virudhunagarcity,'Virudhunagar')
dfc['City']=dfc['City'].replace(Krishnacity,'Krishnagiri')

# %%
ucity = dfc.City.unique()
ucity=sorted(map(str,ucity))
ucity
# Out:
# ['Ariyalur',
#  'Aundipatti',
#  'Chennai',
#  'Cheyyar',
#  'Chinnasalem ',
#  'Chittoor',
#  'Coimbatore',
#  'Cuddalore',
#  'Dharmapuri',
#  'Dindugal',
#  'Erode',
#  'Gobichettipalayam ',
#  'Gowrivakkam',
#  'Hosur',
#  'Kallakurichi ',
#  'Kanchipuram',
#  'Karaikal',
#  'Karaikudi',
#  'Kariapatti',
#  'Karur',
#  'Kovilpatti',
#  'Krishnagiri',
#  'Kumbakonam',
#  'Lalgudi',
#  'MUDUKULATHUR',
#  'Madurai',
#  'Mailadurai',
#  'Mannarkkad',
#  'Mannarkudi',
#  'Marthandam ',
#  'Mayiladuthurai ',
#  'Nagapattinam',
#  'Nagercoil ',
#  'Namakkal',
#  'Nannilam',
#  'Nellore',
#  'Ooty',
#  'Panruti ',
#  'Papanasam ',
#  'Paramakudi',
#  'Perambalur',
#  'Pollachi ',
#  'Puducherry',
#  'Pudukotai',
#  'Rajapalayam',
#  'Ramanathapuram',
#  'Rameshwaram ',
#  'Ranipet',
#  'Salem',
#  'Sankagiri RS',
#  'Sankarankovil ',
#  'Sathyamangalam ',
#  'Sattur',
#  'Sayalkudi',
#  'Surandai ',
#  'Tanjore',
#  'Tenkasi',
#  'Thathanur',
#  'Thirukovilur ',
#  'Thiruvannamalai',
# ...

# %%
dfc
# Out:
#     Are you open to learn ? Do you have laptop    Qualification Degree  \
# 0                       Yes                 Yes     Engineering    B.E
# 1                       Yes                 Yes          Others    BCA
# 2                       Yes                 Yes  Arts & Science    B.A
# 3                       Yes                 Yes  Arts & Science    BCA
# 4                       Yes                 Yes  Arts & Science   M.Sc
# ..                      ...                 ...             ...    ...
# 424                     Yes                 Yes     Engineering    B.E
# 425                     Yes                 Yes     Engineering    B.E
# 426                     Yes                 Yes  Arts & Science   M.Sc
# 427                     Yes                 Yes  Arts & Science   B.Sc
# 428                     Yes                 Yes  Arts & Science  B.Com
#
#     Pass-out Year        City      State                Course
# ...

# %%
dfc = dfc.drop(dfc.columns[[5,9,10,11]],axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 dfc = dfc.drop(dfc.columns[[5,9,10,11]],axis=1)
#
# File c:\users\dhivagar\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py:5196, in Index.__getitem__(self, key)
#    5193     else:
#    5194         key = np.asarray(key, dtype=bool)
# -> 5196 result = getitem(key)
#    5197 # Because we ruled out integer above, we always get an arraylike here
#    5198 if result.ndim > 1:
#
# IndexError: index 9 is out of bounds for axis 0 with size 8

# %%
dfc
# Out:
#     Are you open to learn ? Do you have laptop    Qualification Degree  \
# 0                       Yes                 Yes     Engineering    B.E
# 1                       Yes                 Yes          Others    BCA
# 2                       Yes                 Yes  Arts & Science    B.A
# 3                       Yes                 Yes  Arts & Science    BCA
# 4                       Yes                 Yes  Arts & Science   M.Sc
# ..                      ...                 ...             ...    ...
# 424                     Yes                 Yes     Engineering    B.E
# 425                     Yes                 Yes     Engineering    B.E
# 426                     Yes                 Yes  Arts & Science   M.Sc
# 427                     Yes                 Yes  Arts & Science   B.Sc
# 428                     Yes                 Yes  Arts & Science  B.Com
#
#     Pass-out Year        City      State                Course
# ...

# %%
ustate = dfc.State.unique()
ustate = sorted(map(str,ustate))
ustate
# Out:
# ['Andhra Pradesh', 'Kerala', 'Pudhucherry', 'Tamilnadu']

# %%
Tamilstate = [' Tiruvannamalai',
 'Erode ',
 'India',
 'Namakkal',
 'TAMIL NADU',
 'TAMIL NADU ',
 'TAMILNADU',
 'TAMILNADU ',
 'Tamil Nadu',
 'Tamil Nadu ',
 'Tamil nadhu',
 'Tamil nadu',
 'Tamil nadu ',
 'TamilNadu',
 'TamilNadu ',
 'Tamilnadu',
 'Tamilnadu ',
 'Tamilnadu -Salem ',
 'karur',
 'tamil nadu',
 'tamil nadu ',
 'tamilnadu',
 'tamilnadu ']

pudhucherrystate = ['Pondicherry',
 'Pondicherry ',
 'Puducherry',
 'Puducherry ',]

# %%
dfc['State'] = dfc['State'].replace(Tamilstate,'Tamilnadu')
dfc['State'] = dfc['State'].replace(pudhucherrystate,'Pudhucherry')

# %%
dfc
# Out:
#     Are you open to learn ? Do you have laptop    Qualification Degree  \
# 0                       Yes                 Yes     Engineering    B.E
# 1                       Yes                 Yes          Others    BCA
# 2                       Yes                 Yes  Arts & Science    B.A
# 3                       Yes                 Yes  Arts & Science    BCA
# 4                       Yes                 Yes  Arts & Science   M.Sc
# ..                      ...                 ...             ...    ...
# 424                     Yes                 Yes     Engineering    B.E
# 425                     Yes                 Yes     Engineering    B.E
# 426                     Yes                 Yes  Arts & Science   M.Sc
# 427                     Yes                 Yes  Arts & Science   B.Sc
# 428                     Yes                 Yes  Arts & Science  B.Com
#
#     Pass-out Year        City      State                Course
# ...

# %%
dfc.rename(columns= {'What you wan to learn ?':'Course' },inplace=True)

# %%
dfc
# Out:
#     Are you open to learn ? Do you have laptop    Qualification Degree  \
# 0                       Yes                 Yes     Engineering    B.E
# 1                       Yes                 Yes          Others    BCA
# 2                       Yes                 Yes  Arts & Science    B.A
# 3                       Yes                 Yes  Arts & Science    BCA
# 4                       Yes                 Yes  Arts & Science   M.Sc
# ..                      ...                 ...             ...    ...
# 424                     Yes                 Yes     Engineering    B.E
# 425                     Yes                 Yes     Engineering    B.E
# 426                     Yes                 Yes  Arts & Science   M.Sc
# 427                     Yes                 Yes  Arts & Science   B.Sc
# 428                     Yes                 Yes  Arts & Science  B.Com
#
#     Pass-out Year        City      State                Course
# ...

# %%
ucourse = dfc.Course.unique()
ucourse = sorted(map(str,ucourse))
ucourse
# Out:
# ['Automation testing',
#  'Backend Development',
#  'Blockchain',
#  'Business Development',
#  'Businss Analysis',
#  'Cybersecurity ',
#  'Data Analytics',
#  'Data science ',
#  'DevOps(Cloud)',
#  'Digital Marketing',
#  'Flutter Development',
#  'Frontend Development',
#  'Frontend testing ',
#  'Fullstack',
#  'Graphics Design',
#  'HR/Admin',
#  'Hr recruiter ',
#  'Java',
#  'No Idea',
#  'Python',
#  'Testing',
#  'UI/UX Design',
#  'Video Editing',
#  'Wordpress Development',
#  'Youtube / Content Creation']

# %%
Blockch = ['Blockchain Dev or Devops(Cloud)',
 'Blockchain Developer'] 
DataAna = ['Data Analysis ',
 'Data Analyst',
 'Data Analyst ',
 'Data Analyst and Business Analyst',
 'Data Analytics',
 'Data Analytics ',
 'Data analyst',
 'Data analyst ',
 'Data analytics ']
 
Jav = ['Full Stack java developer',
 'Full stack java developer','Java',
 'Java selenium tester ']
 
Fullsta = ['Full Stack web development or AI based any course ',
 'Full stack Development',
 'Full stack developement ',
 'Full stack developer ',
 'Full stack development ',
 'Full stack web development ',
 'Web Development ']
  
Noide= ['I did not decide what to learn I need your suggestions',
 'Want to discuss']
 
 
 
pytho = ['Python class ', 
 'Python developer ']
 
testi=['Software Testing ',
 'Software Testing and UI/UX',
 'Software testing ',
 'Software testing , manual or automation testing']

# %%
dfc['Course'] = dfc['Course'].replace(Blockch,'Blockchain')
dfc['Course'] = dfc['Course'].replace(DataAna,'Data Analytics')
dfc['Course'] = dfc['Course'].replace(Jav,'Java')
dfc['Course'] = dfc['Course'].replace(Fullsta,'Fullstack')
dfc['Course'] = dfc['Course'].replace(Noide,'No Idea')
dfc['Course'] = dfc['Course'].replace(pytho,'Python')
dfc['Course'] = dfc['Course'].replace(testi,'Testing')

# %%
dfc
# Out:
#     Are you open to learn ? Do you have laptop    Qualification Degree  \
# 0                       Yes                 Yes     Engineering    B.E
# 1                       Yes                 Yes          Others    BCA
# 2                       Yes                 Yes  Arts & Science    B.A
# 3                       Yes                 Yes  Arts & Science    BCA
# 4                       Yes                 Yes  Arts & Science   M.Sc
# ..                      ...                 ...             ...    ...
# 424                     Yes                 Yes     Engineering    B.E
# 425                     Yes                 Yes     Engineering    B.E
# 426                     Yes                 Yes  Arts & Science   M.Sc
# 427                     Yes                 Yes  Arts & Science   B.Sc
# 428                     Yes                 Yes  Arts & Science  B.Com
#
#     Pass-out Year        City      State                Course
# ...

# %%
ucourse = dfc.Course.unique()
ucourse = sorted(map(str,ucourse))
ucourse
# Out:
# ['Automation testing',
#  'Backend Development',
#  'Blockchain',
#  'Business Development',
#  'Businss Analysis',
#  'Cybersecurity ',
#  'Data Analytics',
#  'Data science ',
#  'DevOps(Cloud)',
#  'Digital Marketing',
#  'Flutter Development',
#  'Frontend Development',
#  'Frontend testing ',
#  'Fullstack',
#  'Graphics Design',
#  'HR/Admin',
#  'Hr recruiter ',
#  'Java',
#  'No Idea',
#  'Python',
#  'Testing',
#  'UI/UX Design',
#  'Video Editing',
#  'Wordpress Development',
#  'Youtube / Content Creation']

# %%
dfc
# Out:
#     Are you open to learn ? Do you have laptop    Qualification Degree  \
# 0                       Yes                 Yes     Engineering    B.E
# 1                       Yes                 Yes          Others    BCA
# 2                       Yes                 Yes  Arts & Science    B.A
# 3                       Yes                 Yes  Arts & Science    BCA
# 4                       Yes                 Yes  Arts & Science   M.Sc
# ..                      ...                 ...             ...    ...
# 424                     Yes                 Yes     Engineering    B.E
# 425                     Yes                 Yes     Engineering    B.E
# 426                     Yes                 Yes  Arts & Science   M.Sc
# 427                     Yes                 Yes  Arts & Science   B.Sc
# 428                     Yes                 Yes  Arts & Science  B.Com
#
#     Pass-out Year        City      State                Course
# ...

# %%
filename = "Sencholafinal.xlsx"

dfc.to_excel(filename)
